# %% [markdown]
# <a href="https://colab.research.google.com/github/Onestringlab/osl_statistik/blob/main/3_Statistik_Deskriptif.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Statistik Deskriptif**<br>
# Statistik deskriptif berkaitan dengan penyajian dan pengumpulan data

# %% [markdown]
# **import library yang digunakan**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# membuat data berupa data umur antara 20-35 sebanyak 10 buah
df1 = pd.DataFrame(dict(id=range(10), umur= np.random.randint(20,35, size=10)))
df1
# Out:
#    id  umur
# 0   0    21
# 1   1    25
# 2   2    22
# 3   3    32
# 4   4    30
# 5   5    27
# 6   6    31
# 7   7    33
# 8   8    27
# 9   9    20

# %%
# mencari rata-rata
df1.umur.mean()
# Out:
# 26.8

# %%
# mencari nilai tengah
df1.umur.median()
# Out:
# 27.0

# %%
# mencari data yang paling banyak muncul
df1.umur.mode()
# Out:
# 0    27
# dtype: int64

# %%
# mencari variance
df1.umur.var()
# Out:
# 22.177777777777777

# %%
# mencari standar deviasi
df1.umur.std()
# Out:
# 4.7093288033198295

# %%
# mencari rentang data
df1.umur.max() - df1.umur.min()
# Out:
# 13

# %%
# melihat sebaran menggunakan boxplot
df1.boxplot(column='umur', return_type='axes')

# %% [markdown]
# **Skewness dan Kurtosis![skewness dan kurtosis.JPG](data:image/jpeg;base64,...)**

# %%
# mencari nilai skewness
df1['umur'].skew()
# Out:
# -0.18638654204889551

# %%
# mencari nilai kurtosis
df1['umur'].kurt()
# Out:
# -1.4834127172180032
